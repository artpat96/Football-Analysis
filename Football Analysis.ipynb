# %%
#IMPORTED DATA

#Goals
Mohamed_Salah_G = [19,22,23]
Son_G = [11,17,23]
Jamie_Vardy_G = [23,15,15]
Harry_Kane_G = [18,23,17]
Sadio_Mane_G = [18,11,16]
Wilfried_Zaha_G = [4,11,14]
Kevin_de_Bruyne_G = [13,6,15]
Trent_Alexander_Arnold_G = [4,2,2]
Joao_Cancelo_G = [0,2,1]

#Assists
Mohamed_Salah_A = [10,5,13]
Son_A = [11,10,7]
Jamie_Vardy_A = [5,9,2]
Harry_Kane_A = [2,14,9]
Sadio_Mane_A = [9,8,2]
Wilfried_Zaha_A = [4,2,1]
Kevin_de_Bruyne_A = [20,12,8]
Trent_Alexander_Arnold_A = [13,7,12]
Joao_Cancelo_A = [0,4,7]

#Total_Shots
Mohamed_Salah_TS = [132,126,139]
Son_TS = [81,68,86]
Jamie_Vardy_TS = [89,82,54]
Harry_Kane_TS = [81,137,133]
Sadio_Mane_TS = [77,94,98]
Wilfried_Zaha_TS = [61,60,69]
Kevin_de_Bruyne_TS = [99,80,77]
Trent_Alexander_Arnold_TS = [44,55,51]
Joao_Cancelo_TS = [15,35,81]

#Successful_Dribblings
Mohamed_Salah_SD = [50,36,53]
Son_SD = [62,39,51]
Jamie_Vardy_SD = [23,26,9]
Harry_Kane_SD = [28,52,54]
Sadio_Mane_SD = [69,82,47]
Wilfried_Zaha_SD = [163,55,75]
Kevin_de_Bruyne_SD = [48,48,31]
Trent_Alexander_Arnold_SD = [21,32,19]
Joao_Cancelo_SD = [37,47,56]

#Big_Chances_Created
Mohamed_Salah_BC = [13,12,18]
Son_BC = [12,14,10]
Jamie_Vardy_BC = [12,9,2]
Harry_Kane_BC = [4,14,19]
Sadio_Mane_BC = [10,11,9]
Wilfried_Zaha_BC = [4,4,4]
Kevin_de_Bruyne_BC = [33,19,16]
Trent_Alexander_Arnold_BC = [18,14,18]
Joao_Cancelo_BC = [6,7,8]

#Key_Passes
Mohamed_Salah_KP = [61,57,63]
Son_KP = [41,75,72]
Jamie_Vardy_KP = [32,28,18]
Harry_Kane_KP = [27,49,50]
Sadio_Mane_KP = [59,60,41]
Wilfried_Zaha_KP = [36,30,46]
Kevin_de_Bruyne_KP = [136,80,87]
Trent_Alexander_Arnold_KP = [87,77,90]
Joao_Cancelo_KP = [17,44,39]

#Minutes
Mohamed_Salah_M = [2888,3082,2762]
Son_M = [2486,3125,3022]
Jamie_Vardy_M = [3034,2844,1805]
Harry_Kane_M = [2590,3086,3232]
Sadio_Mane_M = [2755,2812,2825]
Wilfried_Zaha_M = [3280,2613,2762]
Kevin_de_Bruyne_M = [2800,2001,2206]

Trent_Alexander_Arnold_M = [3176,3033,2854]
Joao_Cancelo_M = [1204,2302,3228]

#Seasons
Seasons = ["2019/20","2020/21","2021/22"]

#Players
Players = ["Mohamed_Salah","Son","Jamie_Vardy","Harry_Kane","Sadio_Mane","Wilfried_Zaha","Kevin_de_Bruyne","Trent_Alexander_Arnold","Joao_Cancelo"]
Pdict = {"Mohamed_Salah":0,"Son":1,"Jamie_Vardy":2,"Harry_Kane":3,"Sadio_Mane":4,"Wilfried_Zaha":5,"Kevin_de_Bruyne":6,"Trent_Alexander_Arnold":7,"Joao_Cancelo":8}

#Plots markers
Col = {"Mohamed_Salah":"Red","Son":"Purple","Jamie_Vardy":"Blue","Harry_Kane":"Green","Sadio_Mane":"Black","Wilfried_Zaha":"Magenta","Kevin_de_Bruyne":"Orange","Trent_Alexander_Arnold":"Yellow","Joao_Cancelo":"Blue"}
Mar = {"Mohamed_Salah":"s","Son":"o","Jamie_Vardy":"v","Harry_Kane":"x","Sadio_Mane":"D","Wilfried_Zaha":"^","Kevin_de_Bruyne":"s","Trent_Alexander_Arnold":"x","Joao_Cancelo":"D"}

# %%
#Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Matrixes
Goals = np.array([Mohamed_Salah_G, Son_G, Jamie_Vardy_G, Harry_Kane_G, Sadio_Mane_G, Wilfried_Zaha_G, Kevin_de_Bruyne_G, Trent_Alexander_Arnold_G, Joao_Cancelo_G])
Assists = np.array([Mohamed_Salah_A, Son_A, Jamie_Vardy_A, Harry_Kane_A, Sadio_Mane_A, Wilfried_Zaha_A, Kevin_de_Bruyne_A, Trent_Alexander_Arnold_A, Joao_Cancelo_A])
Total_Shots = np.array([Mohamed_Salah_TS, Son_TS, Jamie_Vardy_TS, Harry_Kane_TS, Sadio_Mane_TS, Wilfried_Zaha_TS, Kevin_de_Bruyne_TS, Trent_Alexander_Arnold_TS, Joao_Cancelo_TS])
Successful_Dribbles = np.array([Mohamed_Salah_SD, Son_SD, Jamie_Vardy_SD, Harry_Kane_SD, Sadio_Mane_SD, Wilfried_Zaha_SD, Kevin_de_Bruyne_SD, Trent_Alexander_Arnold_SD, Joao_Cancelo_SD])
Big_Chances = np.array([Mohamed_Salah_BC, Son_BC, Jamie_Vardy_BC, Harry_Kane_BC, Sadio_Mane_BC, Wilfried_Zaha_BC, Kevin_de_Bruyne_BC, Trent_Alexander_Arnold_BC, Joao_Cancelo_BC])
Key_Passes = np.array([Mohamed_Salah_KP, Son_KP, Jamie_Vardy_KP, Harry_Kane_KP, Sadio_Mane_KP, Wilfried_Zaha_KP, Kevin_de_Bruyne_KP, Trent_Alexander_Arnold_KP, Joao_Cancelo_KP])
Minutes = np.array([Mohamed_Salah_M, Son_M, Jamie_Vardy_M, Harry_Kane_M, Sadio_Mane_M, Wilfried_Zaha_M, Kevin_de_Bruyne_M, Trent_Alexander_Arnold_M, Joao_Cancelo_M])

#DataFrames
GDF = pd.DataFrame(Goals,['Salah','Son','Vardy','Kane','Mane','Zaha','de Bruyne','TAA','Cancelo'],['2019-20','2020-21','2021-22'])
ADF = pd.DataFrame(Assists,['Salah','Son','Vardy','Kane','Mane','Zaha','de Bruyne','TAA','Cancelo'],['2019-20','2020-21','2021-22'])
TSDF = pd.DataFrame(Total_Shots,['Salah','Son','Vardy','Kane','Mane','Zaha','de Bruyne','TAA','Cancelo'],['2019-20','2020-21','2021-22'])
SDDF = pd.DataFrame(Successful_Dribbles,['Salah','Son','Vardy','Kane','Mane','Zaha','de Bruyne','TAA','Cancelo'],['2019-20','2020-21','2021-22'])
BCDF = pd.DataFrame(Big_Chances,['Salah','Son','Vardy','Kane','Mane','Zaha','de Bruyne','TAA','Cancelo'],['2019-20','2020-21','2021-22'])
KPDF = pd.DataFrame(Key_Passes,['Salah','Son','Vardy','Kane','Mane','Zaha','de Bruyne','TAA','Cancelo'],['2019-20','2020-21','2021-22'])
MDF = pd.DataFrame(Minutes,['Salah','Son','Vardy','Kane','Mane','Zaha','de Bruyne','TAA','Cancelo'],['2019-20','2020-21','2021-22'])

#All data in table
All = pd.read_csv('Stats.csv')

# %%
All
# Out:
#              Player  Goals  Assists  TotalShots  SuccessfulDribbles  \
# 0             Salah     19       10         132                  50
# 1             Salah     22        5         126                  36
# 2             Salah     23       13         139                  53
# 3               Son     11       11          81                  62
# 4               Son     17       10          68                  39
# 5               Son     23        7          86                  51
# 6             Vardy     23        5          89                  23
# 7             Vardy     15        9          82                  26
# 8             Vardy     15        2          54                   9
# 9              Kane     18        2          81                  28
# 10             Kane     23       14         137                  52
# 11             Kane     17        9         133                  54
# 12             Mane     18        9          77                  69
# ...

# %%
#Most goals
All[All['Goals'] == All['Goals'].max()]
# Out:
#    Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 2   Salah     23       13         139                  53          18
# 5     Son     23        7          86                  51          10
# 6   Vardy     23        5          89                  23          12
# 10   Kane     23       14         137                  52          14
#
#     KeyPasses  Minutes   Season
# 2          63     2762  2021/22
# 5          72     3022  2021/22
# 6          32     3034  2019/20
# 10         49     3086  2020/21

# %%
#Create Goals per Minutes stat and add it to the main table
GoalsPM = All['Goals']/All['Minutes']
#add this to the end of table
All['GoalsPerMinutes'] = round(GoalsPM,4)
#get 5 best goals per minutes scorers
All.sort_values(by=['GoalsPerMinutes'], ascending = False).head(5)
# Out:
#    Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 8   Vardy     15        2          54                   9           2
# 2   Salah     23       13         139                  53          18
# 5     Son     23        7          86                  51          10
# 6   Vardy     23        5          89                  23          12
# 10   Kane     23       14         137                  52          14
#
#     KeyPasses  Minutes   Season  GoalsPerMinutes
# 8          18     1805  2021/22           0.0083
# 2          63     2762  2021/22           0.0083
# 5          72     3022  2021/22           0.0076
# 6          32     3034  2019/20           0.0076
# 10         49     3086  2020/21           0.0075

# %%
#Mean score each season
round(All.groupby('Season').mean()['GoalsPerMinutes'],5)
# Out:
# C:\Users\artur\AppData\Local\Temp\ipykernel_22072\558661547.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(All.groupby('Season').mean()['GoalsPerMinutes'],5)
# Season
# 2019/20    0.00434
# 2020/21    0.00422
# 2021/22    0.00534
# Name: GoalsPerMinutes, dtype: float64

# %%
#Deleting column from table
All.drop('GoalsPerMinutes', axis = 1, inplace = True)

# %%
#Function to obtain wanted data on the plot
def vis(data,players = Players):
    for i in players:
        plt.plot(Seasons, data[Pdict[i]], c=Col[i], ls='--', marker=Mar[i], ms=8, label=i)
    plt.xlabel('Season')
    plt.legend(loc=0, bbox_to_anchor=(1,1))
    plt.show()

# %%
#Goals per season plot
vis(Goals)

# %%
#Big Chances Created per season plot
vis(Big_Chances)

# %%
#Big Chances Created per Minutes each season plot for 4 best players in that stat
vis(Big_Chances/Minutes,["Mohamed_Salah","Kevin_de_Bruyne","Harry_Kane","Trent_Alexander_Arnold"])

# %%
#Most successful scorers (Goals per Total Shots) each season
GPS = Goals/Total_Shots
#Reshape for DataFrame creation
GPS = GPS.reshape(27,1)

# %%
#Create DataFrame table to see GPS per Player each season
outside = ["Mohamed_Salah","Mohamed_Salah","Mohamed_Salah","Son","Son","Son","Jamie_Vardy","Jamie_Vardy","Jamie_Vardy","Harry_Kane","Harry_Kane","Harry_Kane","Sadio_Mane","Sadio_Mane","Sadio_Mane","Wilfried_Zaha","Wilfried_Zaha","Wilfried_Zaha","Kevin_de_Bruyne","Kevin_de_Bruyne","Kevin_de_Bruyne","Trent_Alexander_Arnold","Trent_Alexander_Arnold","Trent_Alexander_Arnold","Joao_Cancelo","Joao_Cancelo","Joao_Cancelo"]
inside = ["2019/20","2020/21","2021/22","2019/20","2020/21","2021/22","2019/20","2020/21","2021/22","2019/20","2020/21","2021/22","2019/20","2020/21","2021/22","2019/20","2020/21","2021/22","2019/20","2020/21","2021/22","2019/20","2020/21","2021/22","2019/20","2020/21","2021/22"]
index = list(zip(outside,inside))
index = pd.MultiIndex.from_tuples(index)

GPS_DF = pd.DataFrame(GPS,index,['Goals per Shots'])
GPS_DF.index.names = ['Player','Season']
GPS_DF.head(8)
# Out:
#                        Goals per Shots
# Player        Season
# Mohamed_Salah 2019/20         0.143939
#               2020/21         0.174603
#               2021/22         0.165468
# Son           2019/20         0.135802
#               2020/21         0.250000
#               2021/22         0.267442
# Jamie_Vardy   2019/20         0.258427
#               2020/21         0.182927

# %%
#Visualisation
vis(Goals/Total_Shots)

# %%
#Seaborn plots
import warnings
warnings.filterwarnings('ignore')

# %%
#Goals distplot
sns.distplot(All['Goals'],kde=False,bins=15)
# Out:
# <Axes: xlabel='Goals'>

# %%
#Big Chances Creation to Key Passes convertion
sns.jointplot(data=All, x='KeyPasses', y='BigChances', kind='hex', cmap='YlGnBu')

# %%
#Checking goal ratio each season
plt.figure(figsize=(15,3))
sns.countplot(x='Goals',data=All,hue='Season')
# Out:
# <Axes: xlabel='Goals', ylabel='count'>

# %% [markdown]
# ### PLAYING STYLE ANALYSIS

# %%
#Time for style analysis. After finishing analysis I want to know each player's position (defender, midfielder or attacker).
#Firstly we have to see if player is playmaker, winger, attacker or defender.
#Let's check who regularly scores less than 10 goals.

# %%
All[All['Goals']<10]['Player']
# Out:
# 15               Zaha
# 19           deBruyne
# 21    AlexanderArnold
# 22    AlexanderArnold
# 23    AlexanderArnold
# 24            Cancelo
# 25            Cancelo
# 26            Cancelo
# Name: Player, dtype: object

# %%
All[All['Goals']>17]['Player']
# Out:
# 0     Salah
# 1     Salah
# 2     Salah
# 5       Son
# 6     Vardy
# 9      Kane
# 10     Kane
# 12     Mane
# Name: Player, dtype: object

# %%
All.sort_values('TotalShots',ascending=False).head(9)
# Out:
#       Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 2      Salah     23       13         139                  53          18
# 10      Kane     23       14         137                  52          14
# 11      Kane     17        9         133                  54          19
# 0      Salah     19       10         132                  50          13
# 1      Salah     22        5         126                  36          12
# 18  deBruyne     13       20          99                  48          33
# 14      Mane     16        2          98                  47           9
# 13      Mane     11        8          94                  82          11
# 6      Vardy     23        5          89                  23          12
#
#     KeyPasses  Minutes   Season
# 2          63     2762  2021/22
# 10         49     3086  2020/21
# 11         50     3232  2021/22
# 0          61     2888  2019/20
# 1          57     3082  2020/21
# 18        136     2800  2019/20
# ...

# %%
All[All['Player'] == "Vardy"]
# Out:
#   Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 6  Vardy     23        5          89                  23          12
# 7  Vardy     15        9          82                  26           9
# 8  Vardy     15        2          54                   9           2
#
#    KeyPasses  Minutes   Season
# 6         32     3034  2019/20
# 7         28     2844  2020/21
# 8         18     1805  2021/22

# %%
All.sort_values('SuccessfulDribbles',ascending=False).head(9)
# Out:
#      Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 15     Zaha      4        4          61                 163           4
# 13     Mane     11        8          94                  82          11
# 17     Zaha     14        1          69                  75           4
# 12     Mane     18        9          77                  69          10
# 3       Son     11       11          81                  62          12
# 26  Cancelo      1        7          81                  56           8
# 16     Zaha     11        2          60                  55           4
# 11     Kane     17        9         133                  54          19
# 2     Salah     23       13         139                  53          18
#
#     KeyPasses  Minutes   Season
# 15         36     3280  2019/20
# 13         60     2813  2020/21
# 17         46     2762  2021/22
# 12         59     2755  2019/20
# 3          41     2486  2019/20
# 26         39     3228  2021/22
# ...

# %%
All.sort_values('KeyPasses',ascending=False).head(9)
# Out:
#              Player  Goals  Assists  TotalShots  SuccessfulDribbles  \
# 18         deBruyne     13       20          99                  48
# 23  AlexanderArnold      2       12          51                  19
# 21  AlexanderArnold      4       13          44                  21
# 20         deBruyne     15        8          77                  31
# 19         deBruyne      6       12          80                  48
# 22  AlexanderArnold      2        7          55                  32
# 4               Son     17       10          68                  39
# 5               Son     23        7          86                  51
# 2             Salah     23       13         139                  53
#
#     BigChances  KeyPasses  Minutes   Season
# 18          33        136     2800  2019/20
# 23          18         90     2854  2021/22
# 21          18         87     3176  2019/20
# 20          16         87     2206  2021/22
# 19          19         80     2001  2020/21
# ...

# %%
All.sort_values('BigChances',ascending=False).head(9)
# Out:
#              Player  Goals  Assists  TotalShots  SuccessfulDribbles  \
# 18         deBruyne     13       20          99                  48
# 11             Kane     17        9         133                  54
# 19         deBruyne      6       12          80                  48
# 2             Salah     23       13         139                  53
# 23  AlexanderArnold      2       12          51                  19
# 21  AlexanderArnold      4       13          44                  21
# 20         deBruyne     15        8          77                  31
# 4               Son     17       10          68                  39
# 22  AlexanderArnold      2        7          55                  32
#
#     BigChances  KeyPasses  Minutes   Season
# 18          33        136     2800  2019/20
# 11          19         50     3232  2021/22
# 19          19         80     2001  2020/21
# 2           18         63     2762  2021/22
# 23          18         90     2854  2021/22
# ...

# %%
All.sort_values('Assists',ascending=False).head(5)
# Out:
#              Player  Goals  Assists  TotalShots  SuccessfulDribbles  \
# 18         deBruyne     13       20          99                  48
# 10             Kane     23       14         137                  52
# 2             Salah     23       13         139                  53
# 21  AlexanderArnold      4       13          44                  21
# 23  AlexanderArnold      2       12          51                  19
#
#     BigChances  KeyPasses  Minutes   Season
# 18          33        136     2800  2019/20
# 10          14         49     3086  2020/21
# 2           18         63     2762  2021/22
# 21          18         87     3176  2019/20
# 23          18         90     2854  2021/22

# %%
#deBruyne vs Son
BCpM = Big_Chances/Minutes
KPpM = Key_Passes/Minutes
ApKP = Assists/Key_Passes
SDpKP = Successful_Dribbles/Key_Passes

# %%
figsize=(8,4)
plt.ylabel('BigChances per Minutes')
vis(BCpM,["Kevin_de_Bruyne","Son","Trent_Alexander_Arnold"])

figsize=(8,4)
plt.ylabel('KeyPasses per Minutes')
vis(KPpM,["Kevin_de_Bruyne","Son","Trent_Alexander_Arnold"])

figsize=(8,4)
plt.ylabel('Assists per KeyPasses')
vis(ApKP,["Kevin_de_Bruyne","Son","Trent_Alexander_Arnold"])

figsize=(8,4)
plt.ylabel('SuccessfulDribbles per KeyPasses')
vis(SDpKP,["Kevin_de_Bruyne","Son","Trent_Alexander_Arnold"])

# %%
All[All['Assists'] == All['Assists'].max()][['Player','Assists','Season']]
# Out:
#       Player  Assists   Season
# 18  deBruyne       20  2019/20

# %%
#Mane vs Zaha
SDpM = Successful_Dribbles/Minutes
ApSD = Assists/Successful_Dribbles
TSpM = Total_Shots/Minutes

# %%
figsize=(8,4)
plt.ylabel('SuccessfulDribbles per Minutes')
vis(SDpM,["Sadio_Mane","Wilfried_Zaha","Son"])
figsize=(8,4)
plt.ylabel('KeyPasses per Minutes')
vis(KPpM,["Sadio_Mane","Wilfried_Zaha","Son"])
figsize=(8,4)
plt.ylabel('Assists per SuccessfulDribbles')
vis(ApSD,["Sadio_Mane","Wilfried_Zaha","Son"])
figsize=(8,4)
plt.ylabel('TotalShots per Minutes')
vis(TSpM,["Sadio_Mane","Wilfried_Zaha","Son"])

# %%
#Salah vs Kane vs Vardy
GpM = Goals/Minutes
GpTS = Goals/Total_Shots
SDpTS = Successful_Dribbles/Total_Shots

# %%
figsize=(8,4)
plt.ylabel('Goals per Minutes')
vis(GpM,["Mohamed_Salah","Harry_Kane","Jamie_Vardy","Sadio_Mane"])
figsize=(8,4)
plt.ylabel('Goals per TotalShots')
vis(GpTS,["Mohamed_Salah","Harry_Kane","Jamie_Vardy","Sadio_Mane"])
figsize=(8,4)
plt.ylabel('TotalShots per Minutes')
vis(TSpM,["Mohamed_Salah","Harry_Kane","Jamie_Vardy","Sadio_Mane"])
figsize=(8,4)
plt.ylabel('SuccessfulDribbles per TotalShots')
vis(SDpTS,["Mohamed_Salah","Harry_Kane","Jamie_Vardy","Sadio_Mane"])

# %%
#Best Individual
All[(All['Goals']>13) & (All['Assists']>13)][['Player','Season']]
# Out:
#    Player   Season
# 10   Kane  2020/21

# %%
All[(All['Goals']>12) & (All['Assists']>13)][['Player','Season']]
# Out:
#       Player   Season
# 10      Kane  2020/21
# 18  deBruyne  2019/20

# %%
All[(All['Goals']>13) & (All['Assists']>12)][['Player','Season']]
# Out:
#    Player   Season
# 2   Salah  2021/22
# 10   Kane  2020/21

# %%
All[(All['Player'] == "deBruyne") & (All['Season'] == "2019/20")]
# Out:
#       Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 18  deBruyne     13       20          99                  48          33
#
#     KeyPasses  Minutes   Season
# 18        136     2800  2019/20

# %%
All[(All['Player'] == "Kane") & (All['Season'] == "2020/21")]
# Out:
#    Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 10   Kane     23       14         137                  52          14
#
#     KeyPasses  Minutes   Season
# 10         49     3086  2020/21

# %%
All[(All['Player'] == "Salah") & (All['Season'] == "2021/22")]
# Out:
#   Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 2  Salah     23       13         139                  53          18
#
#    KeyPasses  Minutes   Season
# 2         63     2762  2021/22

# %%
All[All['Player'] == "Salah"]
# Out:
#   Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 0  Salah     19       10         132                  50          13
# 1  Salah     22        5         126                  36          12
# 2  Salah     23       13         139                  53          18
#
#    KeyPasses  Minutes   Season
# 0         61     2888  2019/20
# 1         57     3082  2020/21
# 2         63     2762  2021/22

# %%
All[All['Player'] == "Kane"]
# Out:
#    Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 9    Kane     18        2          81                  28           4
# 10   Kane     23       14         137                  52          14
# 11   Kane     17        9         133                  54          19
#
#     KeyPasses  Minutes   Season
# 9          27     2590  2019/20
# 10         49     3086  2020/21
# 11         50     3232  2021/22

# %%
All[All['Player'] == "deBruyne"]
# Out:
#       Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 18  deBruyne     13       20          99                  48          33
# 19  deBruyne      6       12          80                  48          19
# 20  deBruyne     15        8          77                  31          16
#
#     KeyPasses  Minutes   Season
# 18        136     2800  2019/20
# 19         80     2001  2020/21
# 20         87     2206  2021/22

# %%
GA = All['Goals']+All['Assists']
All['GA'] = GA
All.sort_values(by=['GA'], ascending = False).head(9)
# Out:
#       Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 10      Kane     23       14         137                  52          14
# 2      Salah     23       13         139                  53          18
# 18  deBruyne     13       20          99                  48          33
# 5        Son     23        7          86                  51          10
# 0      Salah     19       10         132                  50          13
# 6      Vardy     23        5          89                  23          12
# 4        Son     17       10          68                  39          14
# 12      Mane     18        9          77                  69          10
# 1      Salah     22        5         126                  36          12
#
#     KeyPasses  Minutes   Season  GA
# 10         49     3086  2020/21  37
# 2          63     2762  2021/22  36
# 18        136     2800  2019/20  33
# 5          72     3022  2021/22  30
# 0          61     2888  2019/20  29
# ...

# %%
sns.relplot(data=All, x="Minutes", y="GA", hue="Player")

# %%
sns.jointplot(data=All, x="Goals", y="TotalShots", hue="Player")

# %%
GApM = All['GA']/All['Minutes']
#add
All['GApM'] = round(GApM,3)
#get 5 best goals per minutes scorers
All.sort_values(by=['GApM'], ascending = False).head(6)
# Out:
#       Player  Goals  Assists  TotalShots  SuccessfulDribbles  BigChances  \
# 2      Salah     23       13         139                  53          18
# 18  deBruyne     13       20          99                  48          33
# 10      Kane     23       14         137                  52          14
# 0      Salah     19       10         132                  50          13
# 5        Son     23        7          86                  51          10
# 12      Mane     18        9          77                  69          10
#
#     KeyPasses  Minutes   Season  GA   GApM
# 2          63     2762  2021/22  36  0.013
# 18        136     2800  2019/20  33  0.012
# 10         49     3086  2020/21  37  0.012
# 0          61     2888  2019/20  29  0.010
# 5          72     3022  2021/22  30  0.010
# 12         59     2755  2019/20  27  0.010
